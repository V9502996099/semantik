# %%
# %pip install natasha
# %pip install nltk
import json
import natasha
import nltk
from nltk.corpus import stopwords
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import DataFrame
nltk.download('stopwords')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting natasha
#   Using cached natasha-1.6.0-py3-none-any.whl (34.4 MB)
# Collecting slovnet>=0.6.0
#   Downloading slovnet-0.6.0-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 KB 174.6 kB/s eta 0:00:00a 0:00:01
# Collecting navec>=0.9.0
#   Downloading navec-0.10.0-py3-none-any.whl (23 kB)
# Collecting razdel>=0.5.0
#   Downloading razdel-0.5.0-py3-none-any.whl (21 kB)
# Collecting pymorphy2
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 KB 815.4 kB/s eta 0:00:00:--:--
# Collecting ipymarkup>=0.8.0
#   Downloading ipymarkup-0.9.0-py3-none-any.whl (14 kB)
# Collecting yargy>=0.16.0
#   Downloading yargy-0.16.0-py3-none-any.whl (33 kB)
# Collecting intervaltree>=3
#   Downloading intervaltree-3.1.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (from navec>=0.9.0->natasha) (1.21.5)
# Collecting docopt>=0.6
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pymorphy2-dicts-ru<3.0,>=2.4
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 1.8 MB/s eta 0:00:0000:0100:010m
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting sortedcontainers<3.0,>=2.0
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Building wheels for collected packages: docopt, intervaltree
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=1e44978a6b61e1458867e1a68eb681619683fd1fec49818ef27396817d4298f3
#   Stored in directory: /home/nika/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
#   Building wheel for intervaltree (setup.py) ... done
#   Created wheel for intervaltree: filename=intervaltree-3.1.0-py2.py3-none-any.whl size=26119 sha256=0be10a306f56188c59c5640719908e70cdd5b2edaf0dc0255ca06ef04a94b6b3
#   Stored in directory: /home/nika/.cache/pip/wheels/fa/80/8c/43488a924a046b733b64de3fac99252674c892a4c3801c0a61
# Successfully built docopt intervaltree
# Installing collected packages: sortedcontainers, razdel, pymorphy2-dicts-ru, docopt, dawg-python, pymorphy2, navec, intervaltree, yargy, slovnet, ipymarkup, natasha
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 intervaltree-3.1.0 ipymarkup-0.9.0 natasha-1.6.0 navec-0.10.0 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844 razdel-0.5.0 slovnet-0.6.0 sortedcontainers-2.4.0 yargy-0.16.0
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/nika/.local/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/nika/.local/lib/python3.10/site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: joblib in /home/nika/.local/lib/python3.10/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk) (8.0.3)
# Requirement already satisfied: tqdm in /home/nika/.local/lib/python3.10/site-packages (from nltk) (4.66.4)
# Note: you may need to restart the kernel to use updated packages.
# [nltk_data] Downloading package stopwords to /home/nika/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
with open('articles.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Получаем список заголовков и текстов
titles = [article["title"] for article in data]
texts = [article["body"] for article in data]

# Создаем словарь с заголовками и текстами
articles_dict = dict(zip(titles, texts))

# %%
from natasha import (
    Segmenter,
    MorphVocab,

    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,

    PER,
    NamesExtractor,

    Doc
)

segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = NamesExtractor(morph_vocab)

# %%
from ipymarkup import show_dep_ascii_markup as show_markup
articles = list(articles_dict.values())
article = articles[19]


doc = Doc(str(article))
doc.segment(segmenter)
doc.parse_syntax(syntax_parser)
doc.tag_morph(morph_tagger)

for sentence in doc.sents: # получаем предложения
  sentence.syntax.print()
# Out:
#     ┌────────────────────────► [               punct
#     │ ┌──────────────────────► '               punct
# ┌─┌─│ │ ┌──►┌─────────────┌─── Фото            parataxis
# │ │ │ │ │   │             │ ┌► :               punct
# │ │ │ │ │ ┌─│ ┌─┌─┌───┌─┌─└►└─ Moritz          appos
# │ │ │ │ │ │ │ │ │ │   │ │ └──► Wolf            flat:foreign
# │ │ │ │ │ │ │ │ │ │ ┌►│ │      /               punct
# │ │ │ │ │ │ │ │ │ │ │ │ └────► imagebroker     flat:foreign
# │ │ │ │ │ │ │ │ │ │ │ │   ┌──► .               punct
# │ │ │ │ │ │ │ │ │ │ │ └──►│    com             flat:foreign
# │ │ │ │ │ │ │ │ │ │ │     │ ┌► /               punct
# │ │ │ │ │ │ │ │ │ └►└───┌─└─└─ Globallookpress flat:foreign
# │ │ │ │ │ │ │ │ │       │ └──► .               punct
# │ │ │ │ │ │ │ │ └──────►│      com             flat:foreign
# │ │ │ │ │ │ │ │         └────► '               punct
# │ │ │ │ │ │ │ │           ┌──► ,               punct
# │ │ │ │ │ │ │ │           │ ┌► '               punct
# │ │ │ │ │ │ │ └────────►┌─└─└─ Сервис          conj
# │ │ │ │ │ │ │           │   ┌► по              case
# │ │ │ │ │ │ │         ┌─└──►└─ изучению        nmod
# │ │ │ │ │ │ │         │     ┌► иностранных     amod
# │ │ │ │ │ │ │       ┌─└────►└─ языков          nmod
# │ │ │ │ │ │ │       │   ┌────► Duolingo        appos
# │ │ │ │ │ │ │       │   │ ┌─┌─ удалил
# │ │ │ │ │ │ │       │   │ │ └► материалы       obj
# │ │ │ │ │ │ │       │   │ │ ┌► с               case
# │ │ │ │ │ │ │       │   │ └►└─ пропагандой     obl
# │ │ │ │ │ │ │       │   │ └──► ЛГБТ            nmod
# │ │ │ │ │ │ └──────►│   │      (               punct
# │ │ │ │ │ │         │   │ ┌──► международное   amod
# │ │ │ │ │ │         │   │ │ ┌► общественное    amod
# │ │ │ │ │ └────────►│   └─└─└─ движение        appos
# │ │ │ │ │           └────────► ЛГБТ            nmod
# │ │ └─└─└─────────────┌─┌─┌─── признано
# │ │                   │ │ │ ┌► в               case
# │ │                   │ │ └►└─ России          obl
# │ │                   │ │   ┌► экстремистской  amod
# │ │                   │ └──►└─ организацией    xcomp
# │ │                   │     ┌► и               cc
# │ └──────────────────►│     └─ запрещено       conj
# └────────────────────►│        )               punct
#                       └──────► .               punct
#                     ┌► Об               case
#                   ┌►└─ этом             obl
# ┌───────────────┌─└─┌─ сообщает
# │               │ ┌─└► РИА              nsubj
# │               │ └──► Новости          appos
# │               │   ┌► со               case
# │ ┌────────────►│ ┌─└─ ссылкой          obl
# │ │             │ │ ┌► на               case
# │ │             │ └►└─ Роскомнадзор     nmod
# │ │             └────► .                punct
# │ │   ┌──────────────► '                punct
# │ │   │         ┌────► ,                punct
# │ │   │         │ ┌──► '                punct
# │ │   │         │ │ ┌► «                punct
# │ │   │ ┌──────►└─└─└─ Компания         appos
# │ │   │ │         └──► Duolingo         appos
# │ │ ┌─│ │       ┌─┌─── направила
# │ │ │ │ │       │ │ ┌► в                case
# │ │ │ │ │       │ └►└─ Роскомнадзор     obl
# │ │ │ │ │       │   ┌► ответное         amod
# │ │ │ │ │     ┌─└──►└─ письмо           obj
# │ │ │ │ │     │ ┌────► ,                punct
# │ │ │ │ │     │ │   ┌► в                case
# │ │ │ │ │     │ │ ┌►└─ котором          obl
# │ │ │ │ │   ┌─└►└─└─── подтвердила      acl:relcl
# │ │ │ │ │   │   ┌────► ,                punct
# │ │ │ │ │   │   │ ┌──► что              mark
# │ │ │ │ │   │   │ │ ┌► она              nsubj
# │ │ │ │ │ ┌─└──►└─└─└─ удалила          ccomp
# │ │ │ │ │ │       ┌──► из               case
# │ │ │ │ │ │       │ ┌► обучающего       amod
# │ │ │ │ │ │     ┌►└─└─ приложения       obj
# │ │ │ └─└─└────►│ ┌─── материалы        obj
# │ │ │ │ │       │ │ ┌► ,                punct
# │ │ │ │ │     ┌─└─└►└─ пропагандирующие acl
# │ │ │ │ │     │   ┌──► нетрадиционные   amod
# │ │ │ │ │     │   │ ┌► сексуальные      amod
# │ │ │ │ │     └──►└─└─ отношения        obj
# │ │ │ │ │         └──► »                punct
# │ │ │ │ │         ┌──► ,                punct
# │ │ │ │ │         │ ┌► —                punct
# │ └─│ │ │     ┌►┌─└─└─ говорится        parataxis
# │   │ │ │     │ │   ┌► в                case
# │   │ │ │     │ └──►└─ заявлении        obl
# └──►│ │ │     │        .                punct
#     │ │ └────►│        '                punct
#     │ └──────►│        ,                punct
#     └────────►│        '                punct
#               │     ┌► В                case
#               │   ┌►└─ апреле           obl
#             ┌─└───└─── сообщалось
#             │ │ ┌────► ,                punct
#             │ │ │ ┌──► что              mark
#             │ │ │ │ ┌► Роскомнадзор     nsubj
#             │ └►└─└─└─ предупредил      ccomp
#             │ │   └──► Duolingo         obj
#             │ │     ┌► о                case
#             │ └──►┌─└─ запрете          obl
#             │     └►┌─ публикации       nmod
#             │     ┌─└► материалов       nmod
#             │     │ ┌► с                case
#             │     └►└─ пропагандой      nmod
#             │     └──► ЛГБТ             nmod
#             └────────► .                punct
#           ┌► Ведомство       nsubj
# ┌─────┌─┌─└─ потребовало
# │     │ │ ┌► от              case
# │     │ └►└─ сервиса         obl
# │ ┌─┌─└──►┌─ проверить       xcomp
# │ │ │     └► контент         obj
# │ │ │     ┌► на              case
# │ │ └──►┌─└─ предмет         obl
# │ │     └►┌─ распространения nmod
# │ │   ┌───└► пропаганды      nmod
# │ │   │ ┌──► нетрадиционных  amod
# │ │   │ │ ┌► сексуальных     amod
# │ │   └►└─└─ отношений       nmod
# │ │       ┌► и               cc
# │ └────►┌─└─ устранить       conj
# │       └──► нарушения       obj
# └──────────► .               punct
#               ┌──► Регулятор     nsubj
#               │ ┌► также         advmod
#     ┌─┌───────└─└─ напомнил
#     │ │ ┌────────► ,             punct
#     │ │ │ ┌──────► что           mark
#     │ │ │ │     ┌► за            case
#     │ │ │ │ ┌►┌─└─ нарушение     obl
#     │ │ │ │ │ └──► закона        nmod
#     │ │ │ │ │   ┌► в             case
#     │ │ │ │ │ ┌►└─ России        obl
# ┌─┌─│ └►└─└─└─└─┌─ предусмотрено ccomp
# │ │ │           └► наказание     nsubj:pass
# │ │ │         ┌──► ,             punct
# │ │ │         │ ┌► штраф         nsubj
# │ │ └────────►└─└─ может         ccomp
# │ │       ┌───└──► составить     xcomp
# │ │       │ ┌────► до            case
# │ │       │ │   ┌► четырех       nummod
# │ │       │ │ ┌►└─ миллионов     nummod
# │ │       └►└─└─┌─ рублей        obj
# │ │         │   └► .             punct
# │ │         └────► '             punct
# │ └──────────────► ,             punct
# └────────────────► '             punct
#                 ┌► В             case
#               ┌►└─ феврале       obl
#         ┌─┌───└─┌─ стало
#         │ │     └► известно      xcomp
#         │ │ ┌────► ,             punct
#         │ │ │ ┌──► что           mark
#         │ │ │ │ ┌► Роскомнадзор  nsubj
#         │ └►└─└─└─ начал         ccomp
#         │   ┌─└►┌─ проверку      obj
#         │   │   └► Duolingo      nmod
#         │   │   ┌► на            case
#         │   └►┌─└─ пропаганду    nmod
#         │     └──► ЛГБТ          nmod
#         └────────► .             punct
#           ┌► Перед           case
#   ┌──────►└─ этим            obl
#   │     ┌──► сибирская       amod
#   │     │ ┌► правозащитная   amod
# ┌─│ ┌►┌─└─└─ группа          nsubj
# │ │ │ │   ┌► «               punct
# │ │ │ └►┌─└─ Радетель        appos
# │ │ │   └──► »               punct
# │ └─└───┌─┌─ призвала
# │       │ └► ведомство       obj
# │   ┌───└►┌─ принять         xcomp
# │   │   ┌─└► меры            obj
# │   │   │ ┌► для             case
# │   │   └►└─ привлечения     nmod
# │   │   └──► сервиса         nmod
# │   │     ┌► к               case
# │   │ ┌►┌─└─ ответственности obl
# │   │ │ │ ┌► за              case
# │   │ │ └►└─ пропаганду      nmod
# │   │ │ └──► ЛГБТ            nmod
# │   │ │   ┌► и               cc
# │   └►└─┌─└─ заблокировать   conj
# │     │ └──► приложение      obj
# │     │   ┌► в               case
# │     └►┌─└─ России          obl
# │     │ └──► .               punct
# │     └────► '               punct
# └──────────► ]               punct

# %%
# Получение токенов
for sentence in doc.sents:
  for token in sentence.tokens:
    print(token)

# Заменяем слова на их леммы (начальные формы слова)
for sentence in doc.sents:
  for token in sentence.tokens:
    token.lemmatize(morph_vocab)
  lemmas = {_.text: _.lemma for _ in sentence.tokens}
  print(lemmas.items())
# Out:
# DocToken(stop=1, text='[', id='1_1', head_id='1_34', rel='punct', pos='PUNCT')
# DocToken(start=1, stop=2, text="'", id='1_2', head_id='1_34', rel='punct', pos='PUNCT')
# DocToken(start=2, stop=6, text='Фото', id='1_3', head_id='1_34', rel='parataxis', pos='NOUN', feats=<Inan,Nom,Neut,Sing>)
# DocToken(start=6, stop=7, text=':', id='1_4', head_id='1_5', rel='punct', pos='PUNCT')
# DocToken(start=8, stop=14, text='Moritz', id='1_5', head_id='1_3', rel='appos', pos='X', feats=<Yes>)
# DocToken(start=15, stop=19, text='Wolf', id='1_6', head_id='1_5', rel='flat:foreign', pos='X', feats=<Yes>)
# DocToken(start=20, stop=21, text='/', id='1_7', head_id='1_12', rel='punct', pos='PUNCT')
# DocToken(start=22, stop=33, text='imagebroker', id='1_8', head_id='1_5', rel='flat:foreign', pos='X', feats=<Yes>)
# DocToken(start=33, stop=34, text='.', id='1_9', head_id='1_12', rel='punct', pos='PUNCT')
# DocToken(start=34, stop=37, text='com', id='1_10', head_id='1_5', rel='flat:foreign', pos='X', feats=<Yes>)
# DocToken(start=38, stop=39, text='/', id='1_11', head_id='1_12', rel='punct', pos='PUNCT')
# DocToken(start=40, stop=55, text='Globallookpress', id='1_12', head_id='1_5', rel='flat:foreign', pos='X', feats=<Yes>)
# DocToken(start=55, stop=56, text='.', id='1_13', head_id='1_12', rel='punct', pos='PUNCT')
# DocToken(start=56, stop=59, text='com', id='1_14', head_id='1_5', rel='flat:foreign', pos='X', feats=<Yes>)
# DocToken(start=59, stop=60, text="'", id='1_15', head_id='1_12', rel='punct', pos='PUNCT')
# DocToken(start=60, stop=61, text=',', id='1_16', head_id='1_18', rel='punct', pos='PUNCT')
# DocToken(start=62, stop=63, text="'", id='1_17', head_id='1_18', rel='punct', pos='PUNCT')
# DocToken(start=63, stop=69, text='Сервис', id='1_18', head_id='1_5', rel='conj', pos='NOUN', feats=<Inan,Nom,Masc,Sing>)
# DocToken(start=70, stop=72, text='по', id='1_19', head_id='1_20', rel='case', pos='ADP')
# DocToken(start=73, stop=81, text='изучению', id='1_20', head_id='1_18', rel='nmod', pos='NOUN', feats=<Inan,Dat,Neut,Sing>)
# DocToken(start=82, stop=93, text='иностранных', id='1_21', head_id='1_22', rel='amod', pos='ADJ', feats=<Gen,Pos,Plur>)
# DocToken(start=94, stop=100, text='языков', id='1_22', head_id='1_20', rel='nmod', pos='NOUN', feats=<Inan,Gen,Masc,Plur>)
# DocToken(start=101, stop=109, text='Duolingo', id='1_23', head_id='1_32', rel='appos', pos='PROPN', feats=<Yes>)
# DocToken(start=110, stop=116, text='удалил', id='1_24', head_id='1_0', rel='root', pos='VERB', feats=<Perf,Masc,Ind,Sing,Past,Fin,Act>)
# DocToken(start=117, stop=126, text='материалы', id='1_25', head_id='1_24', rel='obj', pos='NOUN', feats=<Inan,Acc,Masc,Plur>)
# DocToken(start=127, stop=128, text='с', id='1_26', head_id='1_27', rel='case', pos='ADP')
# DocToken(start=129, stop=140, text='пропагандой', id='1_27', head_id='1_24', rel='obl', pos='NOUN', feats=<Inan,Ins,Fem,Sing>)
# DocToken(start=141, stop=145, text='ЛГБТ', id='1_28', head_id='1_27', rel='nmod', pos='PROPN', feats=<Yes>)
# DocToken(start=146, stop=147, text='(', id='1_29', head_id='1_3', rel='punct', pos='PUNCT')
# DocToken(start=147, stop=160, text='международное', id='1_30', head_id='1_32', rel='amod', pos='ADJ', feats=<Nom,Pos,Neut,Sing>)
# DocToken(start=161, stop=173, text='общественное', id='1_31', head_id='1_32', rel='amod', pos='ADJ', feats=<Nom,Pos,Neut,Sing>)
# DocToken(start=174, stop=182, text='движение', id='1_32', head_id='1_5', rel='appos', pos='NOUN', feats=<Inan,Nom,Neut,Sing>)
# DocToken(start=183, stop=187, text='ЛГБТ', id='1_33', head_id='1_22', rel='nmod', pos='PROPN', feats=<Inan,Gen,Neut,Sing>)
# DocToken(start=188, stop=196, text='признано', id='1_34', head_id='1_0', rel='root', pos='VERB', feats=<Perf,Neut,Sing,Past,Short,Part,Pass>)
# DocToken(start=197, stop=198, text='в', id='1_35', head_id='1_36', rel='case', pos='ADP')
# DocToken(start=199, stop=205, text='России', id='1_36', head_id='1_34', rel='obl', pos='PROPN', feats=<Inan,Loc,Fem,Sing>)
# DocToken(start=206, stop=220, text='экстремистской', id='1_37', head_id='1_38', rel='amod', pos='ADJ', feats=<Ins,Pos,Fem,Sing>)
# DocToken(start=221, stop=233, text='организацией', id='1_38', head_id='1_34', rel='xcomp', pos='NOUN', feats=<Inan,Ins,Fem,Sing>)
# DocToken(start=234, stop=235, text='и', id='1_39', head_id='1_40', rel='cc', pos='CCONJ')
# DocToken(start=236, stop=245, text='запрещено', id='1_40', head_id='1_3', rel='conj', pos='VERB', feats=<Perf,Neut,Sing,Past,Short,Part,Pass>)
# DocToken(start=245, stop=246, text=')', id='1_41', head_id='1_3', rel='punct', pos='PUNCT')
# DocToken(start=246, stop=247, text='.', id='1_42', head_id='1_34', rel='punct', pos='PUNCT')
# DocToken(start=248, stop=250, text='Об', id='2_1', head_id='2_2', rel='case', pos='ADP')
# DocToken(start=251, stop=255, text='этом', id='2_2', head_id='2_3', rel='obl', pos='PRON', feats=<Inan,Loc,Neut,Sing>)
# DocToken(start=256, stop=264, text='сообщает', id='2_3', head_id='2_0', rel='root', pos='VERB', feats=<Imp,Ind,Sing,3,Pres,Fin,Act>)
# DocToken(start=265, stop=268, text='РИА', id='2_4', head_id='2_3', rel='nsubj', pos='PROPN', feats=<Inan,Nom,Neut,Sing>)
# DocToken(start=269, stop=276, text='Новости', id='2_5', head_id='2_4', rel='appos', pos='PROPN', feats=<Inan,Nom,Fem,Plur>)
# DocToken(start=277, stop=279, text='со', id='2_6', head_id='2_7', rel='case', pos='ADP')
# DocToken(start=280, stop=287, text='ссылкой', id='2_7', head_id='2_42', rel='obl', pos='NOUN', feats=<Inan,Ins,Fem,Sing>)
# DocToken(start=288, stop=290, text='на', id='2_8', head_id='2_9', rel='case', pos='ADP')
# DocToken(start=291, stop=303, text='Роскомнадзор', id='2_9', head_id='2_7', rel='nmod', pos='PROPN', feats=<Inan,Acc,Masc,Sing>)
# DocToken(start=303, stop=304, text='.', id='2_10', head_id='2_3', rel='punct', pos='PUNCT')
# DocToken(start=304, stop=305, text="'", id='2_11', head_id='2_33', rel='punct', pos='PUNCT')
# DocToken(start=305, stop=306, text=',', id='2_12', head_id='2_15', rel='punct', pos='PUNCT')
# DocToken(start=307, stop=308, text="'", id='2_13', head_id='2_15', rel='punct', pos='PUNCT')
# DocToken(start=308, stop=309, text='«', id='2_14', head_id='2_15', rel='punct', pos='PUNCT')
# DocToken(start=309, stop=317, text='Компания', id='2_15', head_id='2_33', rel='appos', pos='NOUN', feats=<Inan,Nom,Fem,Sing>)
# DocToken(start=318, stop=326, text='Duolingo', id='2_16', head_id='2_15', rel='appos', pos='PROPN', feats=<Yes>)
# DocToken(start=327, stop=336, text='направила', id='2_17', head_id='2_0', rel='root', pos='VERB', feats=<Perf,Fem,Ind,Sing,Past,Fin,Act>)
# DocToken(start=337, stop=338, text='в', id='2_18', head_id='2_19', rel='case', pos='ADP')
# DocToken(start=339, stop=351, text='Роскомнадзор', id='2_19', head_id='2_17', rel='obl', pos='PROPN', feats=<Inan,Acc,Masc,Sing>)
# DocToken(start=352, stop=360, text='ответное', id='2_20', head_id='2_21', rel='amod', pos='ADJ', feats=<Inan,Acc,Pos,Neut,Sing>)
# DocToken(start=361, stop=367, text='письмо', id='2_21', head_id='2_17', rel='obj', pos='NOUN', feats=<Inan,Acc,Neut,Sing>)
# DocToken(start=367, stop=368, text=',', id='2_22', head_id='2_25', rel='punct', pos='PUNCT')
# DocToken(start=369, stop=370, text='в', id='2_23', head_id='2_24', rel='case', pos='ADP')
# DocToken(start=371, stop=378, text='котором', id='2_24', head_id='2_25', rel='obl', pos='PRON', feats=<Loc,Neut,Sing>)
# DocToken(start=379, stop=390, text='подтвердила', id='2_25', head_id='2_21', rel='acl:relcl', pos='VERB', feats=<Perf,Fem,Ind,Sing,Past,Fin,Act>)
# DocToken(start=390, stop=391, text=',', id='2_26', head_id='2_29', rel='punct', pos='PUNCT')
# DocToken(start=392, stop=395, text='что', id='2_27', head_id='2_29', rel='mark', pos='SCONJ')
# DocToken(start=396, stop=399, text='она', id='2_28', head_id='2_29', rel='nsubj', pos='PRON', feats=<Nom,Fem,Sing,3>)
# DocToken(start=400, stop=407, text='удалила', id='2_29', head_id='2_25', rel='ccomp', pos='VERB', feats=<Perf,Fem,Ind,Sing,Past,Fin,Act>)
# DocToken(start=408, stop=410, text='из', id='2_30', head_id='2_32', rel='case', pos='ADP')
# DocToken(start=411, stop=421, text='обучающего', id='2_31', head_id='2_32', rel='amod', pos='ADJ', feats=<Gen,Pos,Neut,Sing>)
# DocToken(start=422, stop=432, text='приложения', id='2_32', head_id='2_35', rel='obj', pos='NOUN', feats=<Inan,Gen,Neut,Sing>)
# DocToken(start=433, stop=442, text='материалы', id='2_33', head_id='2_29', rel='obj', pos='NOUN', feats=<Inan,Acc,Masc,Plur>)
# DocToken(start=442, stop=443, text=',', id='2_34', head_id='2_35', rel='punct', pos='PUNCT')
# DocToken(start=444, stop=460, text='пропагандирующие', id='2_35', head_id='2_33', rel='acl', pos='VERB', feats=<Inan,Imp,Acc,Plur,Pres,Part,Act>)
# DocToken(start=461, stop=475, text='нетрадиционные', id='2_36', head_id='2_38', rel='amod', pos='ADJ', feats=<Inan,Acc,Pos,Plur>)
# DocToken(start=476, stop=487, text='сексуальные', id='2_37', head_id='2_38', rel='amod', pos='ADJ', feats=<Inan,Acc,Pos,Plur>)
# DocToken(start=488, stop=497, text='отношения', id='2_38', head_id='2_35', rel='obj', pos='NOUN', feats=<Inan,Acc,Neut,Plur>)
# DocToken(start=497, stop=498, text='»', id='2_39', head_id='2_38', rel='punct', pos='PUNCT')
# DocToken(start=498, stop=499, text=',', id='2_40', head_id='2_42', rel='punct', pos='PUNCT')
# DocToken(start=500, stop=501, text='—', id='2_41', head_id='2_42', rel='punct', pos='PUNCT')
# DocToken(start=502, stop=511, text='говорится', id='2_42', head_id='2_51', rel='parataxis', pos='VERB', feats=<Imp,Ind,Sing,3,Pres,Fin,Pass>)
# DocToken(start=512, stop=513, text='в', id='2_43', head_id='2_44', rel='case', pos='ADP')
# DocToken(start=514, stop=523, text='заявлении', id='2_44', head_id='2_42', rel='obl', pos='NOUN', feats=<Inan,Loc,Neut,Sing>)
# DocToken(start=523, stop=524, text='.', id='2_45', head_id='2_3', rel='punct', pos='PUNCT')
# DocToken(start=524, stop=525, text="'", id='2_46', head_id='2_33', rel='punct', pos='PUNCT')
# DocToken(start=525, stop=526, text=',', id='2_47', head_id='2_33', rel='punct', pos='PUNCT')
# DocToken(start=527, stop=528, text="'", id='2_48', head_id='2_17', rel='punct', pos='PUNCT')
# DocToken(start=528, stop=529, text='В', id='2_49', head_id='2_50', rel='case', pos='ADP')
# DocToken(start=530, stop=536, text='апреле', id='2_50', head_id='2_51', rel='obl', pos='NOUN', feats=<Inan,Loc,Masc,Sing>)
# DocToken(start=537, stop=547, text='сообщалось', id='2_51', head_id='2_0', rel='root', pos='VERB', feats=<Imp,Neut,Ind,Sing,Past,Fin,Pass>)
# DocToken(start=547, stop=548, text=',', id='2_52', head_id='2_55', rel='punct', pos='PUNCT')
# DocToken(start=549, stop=552, text='что', id='2_53', head_id='2_55', rel='mark', pos='SCONJ')
# DocToken(start=553, stop=565, text='Роскомнадзор', id='2_54', head_id='2_55', rel='nsubj', pos='PROPN', feats=<Inan,Nom,Masc,Sing>)
# DocToken(start=566, stop=577, text='предупредил', id='2_55', head_id='2_51', rel='ccomp', pos='VERB', feats=<Perf,Masc,Ind,Sing,Past,Fin,Act>)
# DocToken(start=578, stop=586, text='Duolingo', id='2_56', head_id='2_55', rel='obj', pos='PROPN', feats=<Yes>)
# DocToken(start=587, stop=588, text='о', id='2_57', head_id='2_58', rel='case', pos='ADP')
# DocToken(start=589, stop=596, text='запрете', id='2_58', head_id='2_55', rel='obl', pos='NOUN', feats=<Inan,Loc,Masc,Sing>)
# DocToken(start=597, stop=607, text='публикации', id='2_59', head_id='2_58', rel='nmod', pos='NOUN', feats=<Inan,Gen,Fem,Sing>)
# DocToken(start=608, stop=618, text='материалов', id='2_60', head_id='2_59', rel='nmod', pos='NOUN', feats=<Inan,Gen,Masc,Plur>)
# DocToken(start=619, stop=620, text='с', id='2_61', head_id='2_62', rel='case', pos='ADP')
# DocToken(start=621, stop=632, text='пропагандой', id='2_62', head_id='2_60', rel='nmod', pos='NOUN', feats=<Inan,Ins,Fem,Sing>)
# DocToken(start=633, stop=637, text='ЛГБТ', id='2_63', head_id='2_62', rel='nmod', pos='PROPN', feats=<Inan,Gen,Masc,Sing>)
# DocToken(start=637, stop=638, text='.', id='2_64', head_id='2_51', rel='punct', pos='PUNCT')
# DocToken(start=639, stop=648, text='Ведомство', id='3_1', head_id='3_2', rel='nsubj', pos='NOUN', feats=<Inan,Nom,Neut,Sing>)
# DocToken(start=649, stop=660, text='потребовало', id='3_2', head_id='3_0', rel='root', pos='VERB', feats=<Perf,Neut,Ind,Sing,Past,Fin,Act>)
# DocToken(start=661, stop=663, text='от', id='3_3', head_id='3_4', rel='case', pos='ADP')
# DocToken(start=664, stop=671, text='сервиса', id='3_4', head_id='3_2', rel='obl', pos='NOUN', feats=<Inan,Gen,Masc,Sing>)
# DocToken(start=672, stop=681, text='проверить', id='3_5', head_id='3_2', rel='xcomp', pos='VERB', feats=<Perf,Inf,Act>)
# DocToken(start=682, stop=689, text='контент', id='3_6', head_id='3_5', rel='obj', pos='NOUN', feats=<Inan,Acc,Masc,Sing>)
# DocToken(start=690, stop=692, text='на', id='3_7', head_id='3_8', rel='case', pos='ADP')
# DocToken(start=693, stop=700, text='предмет', id='3_8', head_id='3_5', rel='obl', pos='NOUN', feats=<Inan,Acc,Masc,Sing>)
# DocToken(start=701, stop=716, text='распространения', id='3_9', head_id='3_8', rel='nmod', pos='NOUN', feats=<Inan,Gen,Neut,Sing>)
# DocToken(start=717, stop=727, text='пропаганды', id='3_10', head_id='3_9', rel='nmod', pos='NOUN', feats=<Inan,Gen,Fem,Sing>)
# DocToken(start=728, stop=742, text='нетрадиционных', id='3_11', head_id='3_13', rel='amod', pos='ADJ', feats=<Gen,Pos,Plur>)
# DocToken(start=743, stop=754, text='сексуальных', id='3_12', head_id='3_13', rel='amod', pos='ADJ', feats=<Gen,Pos,Plur>)
# DocToken(start=755, stop=764, text='отношений', id='3_13', head_id='3_10', rel='nmod', pos='NOUN', feats=<Inan,Gen,Neut,Plur>)
# DocToken(start=765, stop=766, text='и', id='3_14', head_id='3_15', rel='cc', pos='CCONJ')
# DocToken(start=767, stop=776, text='устранить', id='3_15', head_id='3_5', rel='conj', pos='VERB', feats=<Perf,Inf,Act>)
# DocToken(start=777, stop=786, text='нарушения', id='3_16', head_id='3_15', rel='obj', pos='NOUN', feats=<Inan,Acc,Neut,Plur>)
# DocToken(start=786, stop=787, text='.', id='3_17', head_id='3_2', rel='punct', pos='PUNCT')
# DocToken(start=788, stop=797, text='Регулятор', id='4_1', head_id='4_3', rel='nsubj', pos='NOUN', feats=<Inan,Nom,Masc,Sing>)
# DocToken(start=798, stop=803, text='также', id='4_2', head_id='4_3', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=804, stop=812, text='напомнил', id='4_3', head_id='4_0', rel='root', pos='VERB', feats=<Perf,Masc,Ind,Sing,Past,Fin,Act>)
# DocToken(start=812, stop=813, text=',', id='4_4', head_id='4_11', rel='punct', pos='PUNCT')
# DocToken(start=814, stop=817, text='что', id='4_5', head_id='4_11', rel='mark', pos='SCONJ')
# DocToken(start=818, stop=820, text='за', id='4_6', head_id='4_7', rel='case', pos='ADP')
# DocToken(start=821, stop=830, text='нарушение', id='4_7', head_id='4_11', rel='obl', pos='NOUN', feats=<Inan,Acc,Neut,Sing>)
# DocToken(start=831, stop=837, text='закона', id='4_8', head_id='4_7', rel='nmod', pos='NOUN', feats=<Inan,Gen,Masc,Sing>)
# DocToken(start=838, stop=839, text='в', id='4_9', head_id='4_10', rel='case', pos='ADP')
# DocToken(start=840, stop=846, text='России', id='4_10', head_id='4_11', rel='obl', pos='PROPN', feats=<Inan,Loc,Fem,Sing>)
# DocToken(start=847, stop=860, text='предусмотрено', id='4_11', head_id='4_3', rel='ccomp', pos='VERB', feats=<Perf,Neut,Sing,Past,Short,Part,Pass>)
# DocToken(start=861, stop=870, text='наказание', id='4_12', head_id='4_11', rel='nsubj:pass', pos='NOUN', feats=<Inan,Nom,Neut,Sing>)
# DocToken(start=870, stop=871, text=',', id='4_13', head_id='4_15', rel='punct', pos='PUNCT')
# DocToken(start=872, stop=877, text='штраф', id='4_14', head_id='4_15', rel='nsubj', pos='NOUN', feats=<Inan,Nom,Masc,Sing>)
# DocToken(start=878, stop=883, text='может', id='4_15', head_id='4_3', rel='ccomp', pos='VERB', feats=<Imp,Ind,Sing,3,Pres,Fin,Act>)
# DocToken(start=884, stop=893, text='составить', id='4_16', head_id='4_15', rel='xcomp', pos='VERB', feats=<Perf,Inf,Act>)
# DocToken(start=894, stop=896, text='до', id='4_17', head_id='4_20', rel='case', pos='ADP')
# DocToken(start=897, stop=904, text='четырех', id='4_18', head_id='4_19', rel='nummod', pos='NUM', feats=<Gen>)
# DocToken(start=905, stop=914, text='миллионов', id='4_19', head_id='4_20', rel='nummod', pos='NOUN', feats=<Inan,Gen,Masc,Plur>)
# DocToken(start=915, stop=921, text='рублей', id='4_20', head_id='4_16', rel='obj', pos='NOUN', feats=<Inan,Gen,Masc,Plur>)
# DocToken(start=921, stop=922, text='.', id='4_21', head_id='4_20', rel='punct', pos='PUNCT')
# DocToken(start=922, stop=923, text="'", id='4_22', head_id='4_20', rel='punct', pos='PUNCT')
# DocToken(start=923, stop=924, text=',', id='4_23', head_id='4_11', rel='punct', pos='PUNCT')
# DocToken(start=925, stop=926, text="'", id='4_24', head_id='4_11', rel='punct', pos='PUNCT')
# DocToken(start=926, stop=927, text='В', id='4_25', head_id='4_26', rel='case', pos='ADP')
# DocToken(start=928, stop=935, text='феврале', id='4_26', head_id='4_27', rel='obl', pos='NOUN', feats=<Inan,Loc,Masc,Sing>)
# DocToken(start=936, stop=941, text='стало', id='4_27', head_id='4_0', rel='root', pos='VERB', feats=<Perf,Neut,Ind,Sing,Past,Fin,Act>)
# DocToken(start=942, stop=950, text='известно', id='4_28', head_id='4_27', rel='xcomp', pos='ADJ', feats=<Pos,Neut,Sing,Short>)
# DocToken(start=950, stop=951, text=',', id='4_29', head_id='4_32', rel='punct', pos='PUNCT')
# DocToken(start=952, stop=955, text='что', id='4_30', head_id='4_32', rel='mark', pos='SCONJ')
# DocToken(start=956, stop=968, text='Роскомнадзор', id='4_31', head_id='4_32', rel='nsubj', pos='PROPN', feats=<Inan,Nom,Masc,Sing>)
# DocToken(start=969, stop=974, text='начал', id='4_32', head_id='4_27', rel='ccomp', pos='VERB', feats=<Perf,Masc,Ind,Sing,Past,Fin,Act>)
# DocToken(start=975, stop=983, text='проверку', id='4_33', head_id='4_32', rel='obj', pos='NOUN', feats=<Inan,Acc,Fem,Sing>)
# DocToken(start=984, stop=992, text='Duolingo', id='4_34', head_id='4_33', rel='nmod', pos='PROPN', feats=<Yes>)
# DocToken(start=993, stop=995, text='на', id='4_35', head_id='4_36', rel='case', pos='ADP')
# DocToken(start=996, stop=1006, text='пропаганду', id='4_36', head_id='4_33', rel='nmod', pos='NOUN', feats=<Inan,Acc,Fem,Sing>)
# DocToken(start=1007, stop=1011, text='ЛГБТ', id='4_37', head_id='4_36', rel='nmod', pos='PROPN', feats=<Inan,Gen,Neut,Sing>)
# DocToken(start=1011, stop=1012, text='.', id='4_38', head_id='4_27', rel='punct', pos='PUNCT')
# DocToken(start=1013, stop=1018, text='Перед', id='5_1', head_id='5_2', rel='case', pos='ADP')
# DocToken(start=1019, stop=1023, text='этим', id='5_2', head_id='5_9', rel='obl', pos='PRON', feats=<Inan,Ins,Neut,Sing>)
# DocToken(start=1024, stop=1033, text='сибирская', id='5_3', head_id='5_5', rel='amod', pos='ADJ', feats=<Nom,Pos,Fem,Sing>)
# DocToken(start=1034, stop=1047, text='правозащитная', id='5_4', head_id='5_5', rel='amod', pos='ADJ', feats=<Nom,Pos,Fem,Sing>)
# DocToken(start=1048, stop=1054, text='группа', id='5_5', head_id='5_9', rel='nsubj', pos='NOUN', feats=<Inan,Nom,Fem,Sing>)
# DocToken(start=1055, stop=1056, text='«', id='5_6', head_id='5_7', rel='punct', pos='PUNCT')
# DocToken(start=1056, stop=1064, text='Радетель', id='5_7', head_id='5_5', rel='appos', pos='NOUN', feats=<Inan,Nom,Masc,Sing>)
# DocToken(start=1064, stop=1065, text='»', id='5_8', head_id='5_7', rel='punct', pos='PUNCT')
# DocToken(start=1066, stop=1074, text='призвала', id='5_9', head_id='5_0', rel='root', pos='VERB', feats=<Perf,Fem,Ind,Sing,Past,Fin,Act>)
# DocToken(start=1075, stop=1084, text='ведомство', id='5_10', head_id='5_9', rel='obj', pos='NOUN', feats=<Inan,Acc,Neut,Sing>)
# DocToken(start=1085, stop=1092, text='принять', id='5_11', head_id='5_9', rel='xcomp', pos='VERB', feats=<Perf,Inf,Act>)
# DocToken(start=1093, stop=1097, text='меры', id='5_12', head_id='5_11', rel='obj', pos='NOUN', feats=<Inan,Acc,Fem,Plur>)
# DocToken(start=1098, stop=1101, text='для', id='5_13', head_id='5_14', rel='case', pos='ADP')
# DocToken(start=1102, stop=1113, text='привлечения', id='5_14', head_id='5_12', rel='nmod', pos='NOUN', feats=<Inan,Gen,Neut,Sing>)
# DocToken(start=1114, stop=1121, text='сервиса', id='5_15', head_id='5_14', rel='nmod', pos='NOUN', feats=<Inan,Gen,Masc,Sing>)
# DocToken(start=1122, stop=1123, text='к', id='5_16', head_id='5_17', rel='case', pos='ADP')
# DocToken(start=1124, stop=1139, text='ответственности', id='5_17', head_id='5_22', rel='obl', pos='NOUN', feats=<Inan,Dat,Fem,Sing>)
# DocToken(start=1140, stop=1142, text='за', id='5_18', head_id='5_19', rel='case', pos='ADP')
# DocToken(start=1143, stop=1153, text='пропаганду', id='5_19', head_id='5_17', rel='nmod', pos='NOUN', feats=<Inan,Acc,Fem,Sing>)
# DocToken(start=1154, stop=1158, text='ЛГБТ', id='5_20', head_id='5_19', rel='nmod', pos='PROPN', feats=<Inan,Gen,Neut,Sing>)
# DocToken(start=1159, stop=1160, text='и', id='5_21', head_id='5_22', rel='cc', pos='CCONJ')
# DocToken(start=1161, stop=1174, text='заблокировать', id='5_22', head_id='5_11', rel='conj', pos='VERB', feats=<Perf,Inf,Act>)
# DocToken(start=1175, stop=1185, text='приложение', id='5_23', head_id='5_22', rel='obj', pos='NOUN', feats=<Inan,Acc,Neut,Sing>)
# DocToken(start=1186, stop=1187, text='в', id='5_24', head_id='5_25', rel='case', pos='ADP')
# DocToken(start=1188, stop=1194, text='России', id='5_25', head_id='5_22', rel='obl', pos='PROPN', feats=<Inan,Loc,Fem,Sing>)
# DocToken(start=1194, stop=1195, text='.', id='5_26', head_id='5_25', rel='punct', pos='PUNCT')
# DocToken(start=1195, stop=1196, text="'", id='5_27', head_id='5_25', rel='punct', pos='PUNCT')
# DocToken(start=1196, stop=1197, text=']', id='5_28', head_id='5_5', rel='punct', pos='PUNCT')
# dict_items([('[', '['), ("'", "'"), ('Фото', 'фото'), (':', ':'), ('Moritz', 'moritz'), ('Wolf', 'wolf'), ('/', '/'), ('imagebroker', 'imagebroker'), ('.', '.'), ('com', 'com'), ('Globallookpress', 'globallookpress'), (',', ','), ('Сервис', 'сервис'), ('по', 'по'), ('изучению', 'изучение'), ('иностранных', 'иностранный'), ('языков', 'язык'), ('Duolingo', 'duolingo'), ('удалил', 'удалить'), ('материалы', 'материал'), ('с', 'с'), ('пропагандой', 'пропаганда'), ('ЛГБТ', 'лгбт'), ('(', '('), ('международное', 'международный'), ('общественное', 'общественный'), ('движение', 'движение'), ('признано', 'признать'), ('в', 'в'), ('России', 'россия'), ('экстремистской', 'экстремистский'), ('организацией', 'организация'), ('и', 'и'), ('запрещено', 'запретить'), (')', ')')])
# dict_items([('Об', 'о'), ('этом', 'это'), ('сообщает', 'сообщать'), ('РИА', 'риа'), ('Новости', 'новость'), ('со', 'с'), ('ссылкой', 'ссылка'), ('на', 'на'), ('Роскомнадзор', 'роскомнадзор'), ('.', '.'), ("'", "'"), (',', ','), ('«', '«'), ('Компания', 'компания'), ('Duolingo', 'duolingo'), ('направила', 'направить'), ('в', 'в'), ('ответное', 'ответный'), ('письмо', 'письмо'), ('котором', 'который'), ('подтвердила', 'подтвердить'), ('что', 'что'), ('она', 'она'), ('удалила', 'удалить'), ('из', 'из'), ('обучающего', 'обучать'), ('приложения', 'приложение'), ('материалы', 'материал'), ('пропагандирующие', 'пропагандировать'), ('нетрадиционные', 'нетрадиционный'), ('сексуальные', 'сексуальный'), ('отношения', 'отношение'), ('»', '»'), ('—', '—'), ('говорится', 'говориться'), ('заявлении', 'заявление'), ('В', 'в'), ('апреле', 'апрель'), ('сообщалось', 'сообщаться'), ('предупредил', 'предупредить'), ('о', 'о'), ('запрете', 'запрет'), ('публикации', 'публикация'), ('материалов', 'материал'), ('с', 'с'), ('пропагандой', 'пропаганда'), ('ЛГБТ', 'лгбт')])
# dict_items([('Ведомство', 'ведомство'), ('потребовало', 'потребовать'), ('от', 'от'), ('сервиса', 'сервис'), ('проверить', 'проверить'), ('контент', 'контент'), ('на', 'на'), ('предмет', 'предмет'), ('распространения', 'распространение'), ('пропаганды', 'пропаганда'), ('нетрадиционных', 'нетрадиционный'), ('сексуальных', 'сексуальный'), ('отношений', 'отношение'), ('и', 'и'), ('устранить', 'устранить'), ('нарушения', 'нарушение'), ('.', '.')])
# dict_items([('Регулятор', 'регулятор'), ('также', 'также'), ('напомнил', 'напомнить'), (',', ','), ('что', 'что'), ('за', 'за'), ('нарушение', 'нарушение'), ('закона', 'закон'), ('в', 'в'), ('России', 'россия'), ('предусмотрено', 'предусмотреть'), ('наказание', 'наказание'), ('штраф', 'штраф'), ('может', 'мочь'), ('составить', 'составить'), ('до', 'до'), ('четырех', 'четыре'), ('миллионов', 'миллион'), ('рублей', 'рубль'), ('.', '.'), ("'", "'"), ('В', 'в'), ('феврале', 'февраль'), ('стало', 'стать'), ('известно', 'известный'), ('Роскомнадзор', 'роскомнадзор'), ('начал', 'начать'), ('проверку', 'проверка'), ('Duolingo', 'duolingo'), ('на', 'на'), ('пропаганду', 'пропаганда'), ('ЛГБТ', 'лгбт')])
# dict_items([('Перед', 'перед'), ('этим', 'это'), ('сибирская', 'сибирский'), ('правозащитная', 'правозащитный'), ('группа', 'группа'), ('«', '«'), ('Радетель', 'радетель'), ('»', '»'), ('призвала', 'призвать'), ('ведомство', 'ведомство'), ('принять', 'принять'), ('меры', 'мера'), ('для', 'для'), ('привлечения', 'привлечение'), ('сервиса', 'сервис'), ('к', 'к'), ('ответственности', 'ответственность'), ('за', 'за'), ('пропаганду', 'пропаганда'), ('ЛГБТ', 'лгбт'), ('и', 'и'), ('заблокировать', 'заблокировать'), ('приложение', 'приложение'), ('в', 'в'), ('России', 'россия'), ('.', '.'), ("'", "'"), (']', ']')])

# %%
# Записываем в словарь подлежащее : сказуемое
pairs = {}
for sentence in doc.sents:
    nsubj = root = ''
    for token in sentence.tokens:
        token.lemmatize(morph_vocab)
        if token.rel in {"nsubj", "root"}:
            if token.rel == "nsubj":
                nsubj = token.lemma
            elif token.rel == "root":
                root = token.lemma
            if nsubj and root:
                pairs[nsubj] = root

all_pairs = []
for article in articles:
  doc = Doc(str(article))
  doc.segment(segmenter)
  doc.parse_syntax(syntax_parser)
  doc.tag_morph(morph_tagger)
  for sentence in doc.sents:
    nsubj = root = ''
    for token in sentence.tokens:
      token.lemmatize(morph_vocab)
      if token.rel == "nsubj":
        nsubj = token.lemma
      if token.rel == 'root':
        root = token.lemma
      if nsubj and root:
        all_pairs.append((nsubj, root))

print(all_pairs)
all_pairs_count = Counter(all_pairs)
all_pairs_count.most_common(20)
# Out:
# [('половина', 'считать'), ('половина', 'считать'), ('половина', 'считать'), ('ситуация', 'считать'), ('ситуация', 'считать'), ('ситуация', 'считать'), ('ситуация', 'считать'), ('ситуация', 'считать'), ('ситуация', 'считать'), ('ситуация', 'считать'), ('ситуация', 'считать'), ('ситуация', 'считать'), ('ситуация', 'считать'), ('ситуация', 'считать'), ('ситуация', 'считать'), ('ситуация', 'считать'), ('ситуация', 'считать'), ('ситуация', 'считать'), ('опрос', 'свидетельствовать'), ('опрос', 'свидетельствовать'), ('опрос', 'свидетельствовать'), ('опрос', 'свидетельствовать'), ('опрос', 'свидетельствовать'), ('опрос', 'свидетельствовать'), ('опрос', 'свидетельствовать'), ('опрос', 'свидетельствовать'), ('опрос', 'свидетельствовать'), ('опрос', 'свидетельствовать'), ('опрос', 'свидетельствовать'), ('опрос', 'свидетельствовать'), ('страна', 'свидетельствовать'), ('страна', 'свидетельствовать'), ('страна', 'свидетельствовать'), ('страна', 'свидетельствовать'), ('страна', 'свидетельствовать'), ('страна', 'свидетельствовать'), ('страна', 'свидетельствовать'), ('страна', 'свидетельствовать'), ('страна', 'свидетельствовать'), ('процент', 'свидетельствовать'), ('процент', 'свидетельствовать'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('ситуация', 'заявить'), ('ситуация', 'заявить'), ('ситуация', 'заявить'), ('ситуация', 'заявить'), ('ситуация', 'заявить'), ('ситуация', 'заявить'), ('ситуация', 'заявить'), ('ситуация', 'заявить'), ('ситуация', 'заявить'), ('ситуация', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('ситуация', 'заявить'), ('ситуация', 'заявить'), ('ситуация', 'заявить'), ('ситуация', 'заявить'), ('ситуация', 'заявить'), ('процет', 'заявить'), ('процет', 'заявить'), ('процет', 'заявить'), ('процет', 'заявить'), ('процет', 'заявить'), ('процет', 'заявить'), ('процет', 'заявить'), ('процет', 'заявить'), ('процет', 'заявить'), ('процет', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('положение', 'считать'), ('положение', 'считать'), ('положение', 'считать'), ('положение', 'считать'), ('положение', 'считать'), ('положение', 'считать'), ('положение', 'считать'), ('положение', 'считать'), ('положение', 'считать'), ('положение', 'считать'), ('положение', 'считать'), ('положение', 'считать'), ('положение', 'считать'), ('положение', 'считать'), ('положение', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'считать'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('процент', 'заявить'), ('половина', 'заявить'), ('половина', 'заявить'), ('половина', 'заявить'), ('половина', 'заявить'), ('половина', 'заявить'), ('половина', 'заявить'), ...
# [(('процент', 'заявить'), 46),
#  (('президент', 'отмечаться'), 35),
#  (('процент', 'считать'), 32),
#  (('покупатель', 'смочь'), 31),
#  (('стоимость', 'он'), 31),
#  (('оно', 'невозможный'), 28),
#  (('который', 'итог'), 28),
#  (('депутат', 'направить'), 25),
#  (('певица', 'подвергнуться'), 25),
#  (('соединение', 'встречаться'), 25),
#  (('президент', 'стать'), 25),
#  (('страна', 'необходимый'), 25),
#  (('диагноз', 'думать'), 24),
#  (('он', 'рассказать'), 24),
#  (('президент', 'подчеркнуть'), 24),
#  (('фермер', 'выступать'), 24),
#  (('компания', 'заверить'), 23),
#  (('конференция', 'добавить'), 23),
#  (('автомобиль', 'пропускать'), 23),
#  (('она', 'направить'), 23)]

# %%
# Наиболее частовстречающиеся слова, исключая стоп слова, знаки пунктуации и числа, а также англ. n (знак переноса строки)
import string
filtered = []
punctuation = set(string.punctuation + '«»—' + string.digits + 'n')
stop_words = set(stopwords.words('russian'))
for article in articles:
  doc = Doc(str(article))
  doc.segment(segmenter)
  doc.parse_syntax(syntax_parser)
  doc.tag_morph(morph_tagger)
  for sentence in doc.sents:
    for token in sentence.tokens:
      token.lemmatize(morph_vocab)
      if token.lemma not in punctuation and token.lemma not in stop_words:
        filtered.append(token.lemma)

filtered_count = Counter(filtered)
filtered_count.most_common(20)
# Out:
# [('xa', 51),
#  ('россия', 25),
#  ('который', 23),
#  ('это', 22),
#  ('украина', 18),
#  ('фото', 17),
#  ('страна', 17),
#  ('ранее', 14),
#  ('президент', 14),
#  ('процент', 12),
#  ('заявить', 12),
#  ('стать', 12),
#  ('свой', 12),
#  ('весь', 11),
#  ('sprint', 10),
#  ('год', 9),
#  ('слово', 8),
#  ('песков', 8),
#  ('время', 7),
#  ('очень', 7)]

# %%
pairs = [pair[0][0] + ' ' + pair[0][1] for pair in all_pairs_count.most_common(10)]
count = [pair[1] for pair in all_pairs_count.most_common(10)]

plt.figure(figsize=(20, 5))
plt.bar(pairs, count, color = 'green')
plt.title("Наиболее встречающеся пары")
plt.ylabel("Количество")
plt.xlabel("Пара")
plt.tight_layout()
plt.show()

# %%
words = [pair[0] for pair in filtered_count.most_common(10)]
count = [pair[1] for pair in filtered_count.most_common(10)]

plt.figure(figsize=(10, 6))
plt.bar(words, count, color = 'green')
plt.title("Самые популярные слова за исключением стоп-слов")
plt.ylabel("Количество")
plt.xlabel("Слово")
plt.tight_layout()
plt.show()
